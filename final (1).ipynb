# %%
import pandas as pd
df = pd.read_csv("/content/realtor.csv", delimiter=",")
df['Prices'] = df['Prices'].str.replace('$', '')
df['Prices'] = df['Prices'].str.replace(',', '')
df['Prices'] = df['Prices'].astype(float)
df.head()
# Out:
# <ipython-input-83-5eb93a048345>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Prices'] = df['Prices'].str.replace('$', '')
#    Unnamed: 0                                      Address     Prices   Bed  \
# 0           0      237 Dover Pkwy, Stewart Manor, NY 11530   649000.0  4bed
# 1           1          96 Willow St, Garden City, NY 11530   998000.0  3bed
# 2           2    91 Cambridge Ave, Stewart Manor, NY 11530   729000.0  3bed
# 3           3           17 Wyatt Rd, Garden City, NY 11530  1349000.0  4bed
# 4           4  281 New Hyde Park Rd, Garden City, NY 11530   849000.0  3bed
#
#       Bath       Sqft       Sqft Lot   Latitude  Longitude
# 0    2bath  1,910sqft   0.31acre lot  40.715970 -73.685638
# 1    2bath        NaN  6,000sqft lot  40.720859 -73.618847
# 2    2bath        NaN  7,150sqft lot  40.717224 -73.684969
# 3    3bath        NaN  6,100sqft lot  40.733156 -73.628878
# 4  2.5bath        NaN  7,000sqft lot  40.729491 -73.678791

# %%
df = df.iloc[: , 1:]

# %%
df.describe()
df.head()

# %%
print(df)

# %%
df=df[["Prices", "Longitude", "Latitude"]]

# %%
import matplotlib.pyplot as plt
pd.plotting.scatter_matrix(df)
plt.show()

# %%
pd.plotting.scatter_matrix(df[['Prices', 'Latitude', 'Longitude']],figsize=(15,15))
plt.show()
